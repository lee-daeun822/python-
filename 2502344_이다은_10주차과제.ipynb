# %%
#과제25
lux = dict(alpha=30, bravo=40, charlie= 50, delta= 60, echo= 70, foxtrot= 80, golf= 90)
print(lux)
# Out:
# {'alpha': 30, 'bravo': 40, 'charlie': 50, 'delta': 60, 'echo': 70, 'foxtrot': 80, 'golf': 90}

# %%
#과제26

park = {'korean':94, 'english':91, 'mathematics':89, 'science':83}
print(park['english'])
print(park['science'])
# Out:
# 91
# 83

# %%
#과제27

kim = {'korean':94, 'english':91, 'mathematics':89, 'science':83}
kim.update(korean=100, english=100, mathematics=100, science=100)
print(kim)
# Out:
# {'korean': 100, 'english': 100, 'mathematics': 100, 'science': 100}

# %%
#과제28

lee = {'korean':94, 'english':91, 'mathematics':89, 'science':83}

print('english' in lee)
del lee['english']
print(lee)
# Out:
# True
# {'korean': 94, 'mathematics': 89, 'science': 83}

# %%
#과제29

lim = {'korean':94, 'english':91, 'mathematics':89, 'science':83}

print(lim.keys())
print(lim.values())
# Out:
# dict_keys(['korean', 'english', 'mathematics', 'science'])
# dict_values([94, 91, 89, 83])

# %%
#과제30

choi = {'korean':94, 'english':91, 'mathematics':89, 'science':83}
choi = {key: value for key, value in choi.items() if value >= 90}
print(choi)
# Out:
# {'korean': 94, 'english': 91}

# %%
#과제31

yoo = {'korean':94, 'english':91, 'mathematics':89, 'science':83}
average = sum(yoo.values()) / 4
print(average)
# Out:
# 89.25
